# %%
import os
import torch
from torch import nn
import pandas as pd
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader,WeightedRandomSampler
from torch.optim import AdamW,Adam
import torch.nn.functional as F
from matplotlib import pyplot as plt

# %%
data_path = '/home/se/paper/legacy/data'

# %%
from sklearn.preprocessing import LabelEncoder
class StatDataset(Dataset):
    def __init__(self, match,stat,le):
        
        tmp = []
        label = []
        
        for home_pitcher,home_team,away_pitcher,away_team,home_result in list(zip(match['home_pitcher'].values,match['home'].values,match['away_pitcher'],match['away'],match['home_result'])):
            home_player_stat = stat.loc[(stat['name'] == home_pitcher) & (stat['team'] == home_team)]
            away_player_stat = stat.loc[(stat['name'] == away_pitcher) & (stat['team'] == away_team)]

            if (len(home_player_stat) != 0) and (len(away_player_stat) != 0):
                vector = home_player_stat.values.tolist()[0][2:] + away_player_stat.values.tolist()[0][2:]
                tmp.append(vector)
                label.append(home_result)
        
        transform = le.transform(label)
        self.label = torch.tensor(list(transform),dtype=torch.long)
        self.stat = torch.tensor(tmp)
            
    def __len__(self):
        return len(self.stat)

    def __getitem__(self, index):
        return {
                "stat": self.stat[index],
                "label": self.label[index]
                }
        
    def get_num_batches(self, batch_size):
        return len(self) // batch_size

# %%
class legacyClassifier(nn.Module):
    def __init__(self, dropout=0.5):
        super(legacyClassifier, self).__init__()
        self.linear1 = nn.Linear(36, 1024)
        self.dropout2 = nn.Dropout(dropout)
        self.linear2 = nn.Linear(1024,3)
        
    def forward(self, input_id):
        linear_output = self.linear1(input_id)
        dropout_output1 = self.dropout2(linear_output)
        linear_output1 = self.linear2(dropout_output1)
        return linear_output1

# %%
stat = pd.read_csv(os.path.join(data_path,'average.csv'))
match = pd.read_csv(os.path.join(data_path,'match_day.csv'))
le = LabelEncoder()
_=le.fit(['승','패','무승부'])

# %%
train_match,valid_match = train_test_split(match,shuffle=True,random_state=56)

# %%
train_dataset = StatDataset(train_match,stat,le)
valid_dataset = StatDataset(valid_match,stat,le)
print(len(train_dataset),len(valid_dataset))
# Out:
# 576 189

# %%
batch_size = 16
epochs = 100
device='cuda'

# %%
le.classes_
# Out:
# array(['무승부', '승', '패'], dtype='<U3')

# %% [markdown]
# train_class = pd.DataFrame(train_dataset.label)
# train_class_counts = [len(train_class.loc[train_class[0] == 0]) , len(train_class.loc[train_class[0] == 1])  , len(train_class.loc[train_class[0] == 2])]
# train_num_samples = sum(train_class_counts)
# train_labels = list(train_class.values.reshape(-1))
#
# train_class_weights = [train_num_samples / train_class_counts[i] for i in range(len(train_class_counts))]
#
# # 해당 데이터의 label에 해당되는 가중치
# train_weights = [train_class_weights[train_labels[i]] for i in range(int(train_num_samples))] #해당 레이블마다의 가중치 비율
# train_sampler = WeightedRandomSampler(torch.DoubleTensor(train_weights), int(train_num_samples))

# %% [markdown]
# valid_class = pd.DataFrame(valid_dataset.label)
# valid_class_counts = [len(valid_class.loc[train_class[0] == 0]) , len(valid_class.loc[train_class[0] == 1])  , len(valid_class.loc[train_class[0] == 2])]
# valid_num_samples = sum(valid_class_counts)
# valid_labels = list(valid_class.values.reshape(-1))
#
# valid_class_weights = [valid_num_samples / valid_class_counts[i] for i in range(len(valid_class_counts))]
#
# # 해당 데이터의 label에 해당되는 가중치
# valid_weights = [valid_class_weights[valid_labels[i]] for i in range(int(valid_num_samples))] #해당 레이블마다의 가중치 비율
# valid_sampler = WeightedRandomSampler(torch.DoubleTensor(valid_weights), int(valid_num_samples))

# %% [markdown]
# train_class_weights

# %% [markdown]
# valid_class_weights

# %%
classifier = legacyClassifier()
classifier.cuda()
optimizer = torch.optim.AdamW(classifier.parameters(), lr=1e-3)

# %%
criterion = nn.CrossEntropyLoss()
_=criterion.cuda()

# %%
train_dataloader = DataLoader(train_dataset, batch_size=batch_size)
val_dataloader = DataLoader(valid_dataset, batch_size=batch_size)

# %%
train_loss = []
train_acc = []

valid_loss = []
valid_acc = []

# %%
classifier
# Out:
# legacyClassifier(
#   (linear1): Linear(in_features=36, out_features=1024, bias=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (linear2): Linear(in_features=1024, out_features=3, bias=True)
# )

# %%
count = []

# %%
classifier.zero_grad()
for epoch in tqdm(range(epochs),total=epochs):
    
    total_acc_train = 0
    total_loss_train = 0
    classifier.train()
    for i,batch in enumerate(train_dataloader):

        train_label = batch['label'].to(device)
        train_stat = batch['stat'].to(device)
        
        output = classifier(train_stat)
        output = output.squeeze(1)
        batch_loss = criterion(output.float(), train_label)
        
        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()
        
        total_loss_train += batch_loss.item()
        
        correct_prediction = torch.argmax(F.softmax(output, dim=1), 1) == train_label

        acc = correct_prediction.float().mean()
#         acc = (output.round() == train_label).sum().item()
        total_acc_train += acc.item()
        
    train_loss.append(total_loss_train/len(train_dataloader))
    train_acc.append(total_acc_train/len(train_dataloader))
            
    total_acc_val = 0
    total_loss_val = 0
    
    with  torch.no_grad():
        classifier.eval()
        cnt = [0,0,0]
        for i,batch in enumerate(val_dataloader):
            
            val_label = batch['label'].to(device)
            val_stat = batch['stat'].to(device)

            output = classifier(val_stat)
            output = output.squeeze(1)
            batch_loss = criterion(output.float(), val_label)
            
            total_loss_val += batch_loss.item()
            correct_prediction = torch.argmax(F.softmax(output, dim=1), 1) == val_label
            acc = correct_prediction.float().mean()
#             acc = (output.round() == val_label).sum().item()
            total_acc_val += acc.item()
            for value in torch.argmax(F.softmax(output, dim=1), 1):
                cnt[int(value.item())] += 1
        count.append(cnt)
        valid_loss.append(total_loss_val/ len(val_dataloader))
        valid_acc.append(total_acc_val/ len(val_dataloader))
#         torch.save(classifier.state_dict(), './model{}.pt'.format(epoch))
 
        print(
                f'Epochs: {epoch + 1} | Train Loss: {total_loss_train / len(train_dataloader): .3f} \
                | Train Accuracy: {total_acc_train / len(train_dataloader): .3f} \
                | Val Loss: {total_loss_val / len(val_dataloader): .3f} \
                | Val Accuracy: {total_acc_val / len(val_dataloader): .3f}')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epochs: 1 | Train Loss:  1.123                 | Train Accuracy:  0.528                 | Val Loss:  0.799                 | Val Accuracy:  0.511
# Epochs: 2 | Train Loss:  1.013                 | Train Accuracy:  0.516                 | Val Loss:  0.745                 | Val Accuracy:  0.550
# Epochs: 3 | Train Loss:  0.951                 | Train Accuracy:  0.497                 | Val Loss:  0.788                 | Val Accuracy:  0.522
# Epochs: 4 | Train Loss:  0.886                 | Train Accuracy:  0.550                 | Val Loss:  0.735                 | Val Accuracy:  0.527
# Epochs: 5 | Train Loss:  0.928                 | Train Accuracy:  0.524                 | Val Loss:  0.763                 | Val Accuracy:  0.529
# Epochs: 6 | Train Loss:  0.897                 | Train Accuracy:  0.556                 | Val Loss:  0.714                 | Val Accuracy:  0.536
# Epochs: 7 | Train Loss:  0.886                 | Train Accuracy:  0.510                 | Val Loss:  0.736                 | Val Accuracy:  0.511
# Epochs: 8 | Train Loss:  0.932                 | Train Accuracy:  0.507                 | Val Loss:  0.870                 | Val Accuracy:  0.522
# Epochs: 9 | Train Loss:  0.884                 | Train Accuracy:  0.510                 | Val Loss:  0.734                 | Val Accuracy:  0.537
# Epochs: 10 | Train Loss:  0.831                 | Train Accuracy:  0.538                 | Val Loss:  0.728                 | Val Accuracy:  0.503
# Epochs: 11 | Train Loss:  0.918                 | Train Accuracy:  0.524                 | Val Loss:  0.777                 | Val Accuracy:  0.532
# Epochs: 12 | Train Loss:  0.893                 | Train Accuracy:  0.517                 | Val Loss:  0.747                 | Val Accuracy:  0.558
# Epochs: 13 | Train Loss:  0.857                 | Train Accuracy:  0.521                 | Val Loss:  0.765                 | Val Accuracy:  0.524
# Epochs: 14 | Train Loss:  0.906                 | Train Accuracy:  0.498                 | Val Loss:  0.705                 | Val Accuracy:  0.534
# Epochs: 15 | Train Loss:  0.850                 | Train Accuracy:  0.540                 | Val Loss:  0.760                 | Val Accuracy:  0.516
# Epochs: 16 | Train Loss:  0.913                 | Train Accuracy:  0.510                 | Val Loss:  0.831                 | Val Accuracy:  0.522
# Epochs: 17 | Train Loss:  0.863                 | Train Accuracy:  0.531                 | Val Loss:  0.743                 | Val Accuracy:  0.508
# Epochs: 18 | Train Loss:  0.934                 | Train Accuracy:  0.521                 | Val Loss:  0.761                 | Val Accuracy:  0.546
# Epochs: 19 | Train Loss:  0.819                 | Train Accuracy:  0.536                 | Val Loss:  0.737                 | Val Accuracy:  0.512
# Epochs: 20 | Train Loss:  0.854                 | Train Accuracy:  0.545                 | Val Loss:  0.753                 | Val Accuracy:  0.512
# Epochs: 21 | Train Loss:  0.885                 | Train Accuracy:  0.498                 | Val Loss:  0.773                 | Val Accuracy:  0.527
# Epochs: 22 | Train Loss:  0.850                 | Train Accuracy:  0.524                 | Val Loss:  0.737                 | Val Accuracy:  0.549
# Epochs: 23 | Train Loss:  0.823                 | Train Accuracy:  0.554                 | Val Loss:  0.768                 | Val Accuracy:  0.507
# Epochs: 24 | Train Loss:  0.866                 | Train Accuracy:  0.502                 | Val Loss:  0.766                 | Val Accuracy:  0.518
# Epochs: 25 | Train Loss:  0.878                 | Train Accuracy:  0.519                 | Val Loss:  0.746                 | Val Accuracy:  0.542
# Epochs: 26 | Train Loss:  0.884                 | Train Accuracy:  0.512                 | Val Loss:  0.725                 | Val Accuracy:  0.494
# Epochs: 27 | Train Loss:  0.842                 | Train Accuracy:  0.509                 | Val Loss:  0.731                 | Val Accuracy:  0.552
# Epochs: 28 | Train Loss:  0.930                 | Train Accuracy:  0.469                 | Val Loss:  0.720                 | Val Accuracy:  0.549
# Epochs: 29 | Train Loss:  0.850                 | Train Accuracy:  0.533                 | Val Loss:  0.711                 | Val Accuracy:  0.503
# Epochs: 30 | Train Loss:  0.834                 | Train Accuracy:  0.524                 | Val Loss:  0.728                 | Val Accuracy:  0.540
# Epochs: 31 | Train Loss:  0.882                 | Train Accuracy:  0.500                 | Val Loss:  0.751                 | Val Accuracy:  0.549
# Epochs: 32 | Train Loss:  0.830                 | Train Accuracy:  0.521                 | Val Loss:  0.742                 | Val Accuracy:  0.529
# Epochs: 33 | Train Loss:  0.830                 | Train Accuracy:  0.526                 | Val Loss:  0.747                 | Val Accuracy:  0.551
# Epochs: 34 | Train Loss:  0.797                 | Train Accuracy:  0.554                 | Val Loss:  0.741                 | Val Accuracy:  0.525
# Epochs: 35 | Train Loss:  0.796                 | Train Accuracy:  0.517                 | Val Loss:  0.723                 | Val Accuracy:  0.486
# Epochs: 36 | Train Loss:  0.840                 | Train Accuracy:  0.491                 | Val Loss:  0.742                 | Val Accuracy:  0.502
# Epochs: 37 | Train Loss:  0.760                 | Train Accuracy:  0.547                 | Val Loss:  0.717                 | Val Accuracy:  0.492
# Epochs: 38 | Train Loss:  0.837                 | Train Accuracy:  0.542                 | Val Loss:  0.731                 | Val Accuracy:  0.579
# Epochs: 39 | Train Loss:  0.841                 | Train Accuracy:  0.526                 | Val Loss:  0.743                 | Val Accuracy:  0.550
# Epochs: 40 | Train Loss:  0.812                 | Train Accuracy:  0.523                 | Val Loss:  0.726                 | Val Accuracy:  0.546
# Epochs: 41 | Train Loss:  0.790                 | Train Accuracy:  0.521                 | Val Loss:  0.741                 | Val Accuracy:  0.512
# Epochs: 42 | Train Loss:  0.853                 | Train Accuracy:  0.497                 | Val Loss:  0.775                 | Val Accuracy:  0.550
# Epochs: 43 | Train Loss:  0.797                 | Train Accuracy:  0.528                 | Val Loss:  0.720                 | Val Accuracy:  0.504
# Epochs: 44 | Train Loss:  0.815                 | Train Accuracy:  0.547                 | Val Loss:  0.728                 | Val Accuracy:  0.520
# Epochs: 45 | Train Loss:  0.778                 | Train Accuracy:  0.542                 | Val Loss:  0.743                 | Val Accuracy:  0.537
# Epochs: 46 | Train Loss:  0.761                 | Train Accuracy:  0.578                 | Val Loss:  0.746                 | Val Accuracy:  0.502
# Epochs: 47 | Train Loss:  0.811                 | Train Accuracy:  0.488                 | Val Loss:  0.741                 | Val Accuracy:  0.549
# Epochs: 48 | Train Loss:  0.833                 | Train Accuracy:  0.507                 | Val Loss:  0.746                 | Val Accuracy:  0.555
# Epochs: 49 | Train Loss:  0.825                 | Train Accuracy:  0.521                 | Val Loss:  0.728                 | Val Accuracy:  0.525
# Epochs: 50 | Train Loss:  0.828                 | Train Accuracy:  0.540                 | Val Loss:  0.758                 | Val Accuracy:  0.523
# Epochs: 51 | Train Loss:  0.838                 | Train Accuracy:  0.521                 | Val Loss:  0.741                 | Val Accuracy:  0.549
# Epochs: 52 | Train Loss:  0.837                 | Train Accuracy:  0.533                 | Val Loss:  0.754                 | Val Accuracy:  0.519
# Epochs: 53 | Train Loss:  0.842                 | Train Accuracy:  0.505                 | Val Loss:  0.718                 | Val Accuracy:  0.541
# Epochs: 54 | Train Loss:  0.821                 | Train Accuracy:  0.505                 | Val Loss:  0.718                 | Val Accuracy:  0.526
# Epochs: 55 | Train Loss:  0.840                 | Train Accuracy:  0.549                 | Val Loss:  0.742                 | Val Accuracy:  0.547
# Epochs: 56 | Train Loss:  0.881                 | Train Accuracy:  0.517                 | Val Loss:  0.741                 | Val Accuracy:  0.528
# Epochs: 57 | Train Loss:  0.864                 | Train Accuracy:  0.528                 | Val Loss:  0.790                 | Val Accuracy:  0.523
# Epochs: 58 | Train Loss:  0.801                 | Train Accuracy:  0.547                 | Val Loss:  0.745                 | Val Accuracy:  0.534
# Epochs: 59 | Train Loss:  0.828                 | Train Accuracy:  0.533                 | Val Loss:  0.740                 | Val Accuracy:  0.554
# Epochs: 60 | Train Loss:  0.826                 | Train Accuracy:  0.514                 | Val Loss:  0.741                 | Val Accuracy:  0.529
# Epochs: 61 | Train Loss:  0.804                 | Train Accuracy:  0.543                 | Val Loss:  0.738                 | Val Accuracy:  0.554
# Epochs: 62 | Train Loss:  0.828                 | Train Accuracy:  0.497                 | Val Loss:  0.770                 | Val Accuracy:  0.514
# Epochs: 63 | Train Loss:  0.824                 | Train Accuracy:  0.523                 | Val Loss:  0.745                 | Val Accuracy:  0.544
# Epochs: 64 | Train Loss:  0.797                 | Train Accuracy:  0.545                 | Val Loss:  0.733                 | Val Accuracy:  0.520
# Epochs: 65 | Train Loss:  0.774                 | Train Accuracy:  0.550                 | Val Loss:  0.733                 | Val Accuracy:  0.549
# Epochs: 66 | Train Loss:  0.811                 | Train Accuracy:  0.512                 | Val Loss:  0.792                 | Val Accuracy:  0.529
# Epochs: 67 | Train Loss:  0.808                 | Train Accuracy:  0.517                 | Val Loss:  0.742                 | Val Accuracy:  0.518
# Epochs: 68 | Train Loss:  0.791                 | Train Accuracy:  0.535                 | Val Loss:  0.761                 | Val Accuracy:  0.502
# Epochs: 69 | Train Loss:  0.786                 | Train Accuracy:  0.552                 | Val Loss:  0.733                 | Val Accuracy:  0.493
# Epochs: 70 | Train Loss:  0.784                 | Train Accuracy:  0.517                 | Val Loss:  0.722                 | Val Accuracy:  0.492
# Epochs: 71 | Train Loss:  0.778                 | Train Accuracy:  0.519                 | Val Loss:  0.734                 | Val Accuracy:  0.566
# Epochs: 72 | Train Loss:  0.783                 | Train Accuracy:  0.540                 | Val Loss:  0.717                 | Val Accuracy:  0.497
# Epochs: 73 | Train Loss:  0.781                 | Train Accuracy:  0.533                 | Val Loss:  0.740                 | Val Accuracy:  0.534
# Epochs: 74 | Train Loss:  0.784                 | Train Accuracy:  0.526                 | Val Loss:  0.716                 | Val Accuracy:  0.492
# Epochs: 75 | Train Loss:  0.778                 | Train Accuracy:  0.530                 | Val Loss:  0.723                 | Val Accuracy:  0.490
# Epochs: 76 | Train Loss:  0.816                 | Train Accuracy:  0.512                 | Val Loss:  0.745                 | Val Accuracy:  0.534
# Epochs: 77 | Train Loss:  0.810                 | Train Accuracy:  0.535                 | Val Loss:  0.716                 | Val Accuracy:  0.512
# Epochs: 78 | Train Loss:  0.782                 | Train Accuracy:  0.559                 | Val Loss:  0.768                 | Val Accuracy:  0.523
# Epochs: 79 | Train Loss:  0.780                 | Train Accuracy:  0.562                 | Val Loss:  0.722                 | Val Accuracy:  0.493
# Epochs: 80 | Train Loss:  0.792                 | Train Accuracy:  0.549                 | Val Loss:  0.730                 | Val Accuracy:  0.514
# Epochs: 81 | Train Loss:  0.795                 | Train Accuracy:  0.538                 | Val Loss:  0.751                 | Val Accuracy:  0.559
# Epochs: 82 | Train Loss:  0.805                 | Train Accuracy:  0.536                 | Val Loss:  0.738                 | Val Accuracy:  0.520
# Epochs: 83 | Train Loss:  0.848                 | Train Accuracy:  0.531                 | Val Loss:  0.746                 | Val Accuracy:  0.523
# Epochs: 84 | Train Loss:  0.787                 | Train Accuracy:  0.545                 | Val Loss:  0.729                 | Val Accuracy:  0.565
# Epochs: 85 | Train Loss:  0.767                 | Train Accuracy:  0.531                 | Val Loss:  0.729                 | Val Accuracy:  0.528
# Epochs: 86 | Train Loss:  0.780                 | Train Accuracy:  0.561                 | Val Loss:  0.758                 | Val Accuracy:  0.524
# Epochs: 87 | Train Loss:  0.788                 | Train Accuracy:  0.547                 | Val Loss:  0.741                 | Val Accuracy:  0.550
# Epochs: 88 | Train Loss:  0.777                 | Train Accuracy:  0.531                 | Val Loss:  0.737                 | Val Accuracy:  0.534
# Epochs: 89 | Train Loss:  0.744                 | Train Accuracy:  0.561                 | Val Loss:  0.733                 | Val Accuracy:  0.507
# Epochs: 90 | Train Loss:  0.763                 | Train Accuracy:  0.536                 | Val Loss:  0.724                 | Val Accuracy:  0.514
# Epochs: 91 | Train Loss:  0.774                 | Train Accuracy:  0.542                 | Val Loss:  0.746                 | Val Accuracy:  0.519
# Epochs: 92 | Train Loss:  0.799                 | Train Accuracy:  0.517                 | Val Loss:  0.736                 | Val Accuracy:  0.529
# Epochs: 93 | Train Loss:  0.759                 | Train Accuracy:  0.552                 | Val Loss:  0.733                 | Val Accuracy:  0.507
# Epochs: 94 | Train Loss:  0.793                 | Train Accuracy:  0.528                 | Val Loss:  0.737                 | Val Accuracy:  0.544
# Epochs: 95 | Train Loss:  0.826                 | Train Accuracy:  0.524                 | Val Loss:  0.741                 | Val Accuracy:  0.538
# Epochs: 96 | Train Loss:  0.801                 | Train Accuracy:  0.531                 | Val Loss:  0.749                 | Val Accuracy:  0.534
# Epochs: 97 | Train Loss:  0.808                 | Train Accuracy:  0.521                 | Val Loss:  0.752                 | Val Accuracy:  0.556
# Epochs: 98 | Train Loss:  0.771                 | Train Accuracy:  0.554                 | Val Loss:  0.733                 | Val Accuracy:  0.493
# Epochs: 99 | Train Loss:  0.786                 | Train Accuracy:  0.535                 | Val Loss:  0.755                 | Val Accuracy:  0.566
# Epochs: 100 | Train Loss:  0.775                 | Train Accuracy:  0.536                 | Val Loss:  0.723                 | Val Accuracy:  0.544

# %%
plt.plot(valid_loss,color='red',label = 'valid')
plt.plot(train_loss,color='blue',label = 'train')
plt.show()

# %%
plt.plot(valid_acc,color='red',label = 'valid')
plt.plot(train_acc,color='blue',label = 'train')
plt.show()

# %%
plt.plot(count)
plt.show()

# %%
count
# Out:
# [[0, 8, 181],
#  [0, 89, 100],
#  [0, 20, 169],
#  [0, 61, 128],
#  [0, 61, 128],
#  [0, 78, 111],
#  [0, 42, 147],
#  [0, 2, 187],
#  [0, 56, 133],
#  [0, 54, 135],
#  [0, 10, 179],
#  [0, 74, 115],
#  [0, 52, 137],
#  [0, 106, 83],
#  [0, 17, 172],
#  [0, 14, 175],
#  [0, 59, 130],
#  [0, 60, 129],
#  [0, 40, 149],
#  [0, 40, 149],
#  [0, 9, 180],
#  [0, 27, 162],
#  [0, 35, 154],
#  [0, 29, 160],
#  [0, 83, 106],
#  [2, 64, 123],
#  [0, 79, 110],
#  [0, 107, 82],
#  [0, 98, 91],
#  [0, 61, 128],
#  [0, 153, 36],
#  [0, 95, 94],
#  [0, 109, 80],
#  [0, 36, 153],
#  [0, 63, 126],
#  [0, 36, 153],
#  [0, 54, 135],
#  [0, 84, 105],
#  [0, 133, 56],
#  [0, 98, 91],
#  [0, 36, 153],
#  [0, 125, 64],
#  [0, 72, 117],
#  [0, 89, 100],
#  [0, 80, 109],
#  [0, 52, 137],
#  [0, 125, 64],
#  [0, 96, 93],
#  [0, 92, 97],
#  [0, 128, 61],
#  [0, 131, 58],
#  [0, 119, 70],
#  [0, 73, 116],
#  [0, 80, 109],
#  [0, 96, 93],
#  [0, 141, 48],
#  [0, 156, 33],
#  [0, 108, 81],
#  [0, 144, 45],
#  [0, 123, 66],
#  [0, 140, 49],
#  [0, 114, 75],
#  [0, 120, 69],
#  [0, 97, 92],
#  [0, 109, 80],
#  [0, 111, 78],
#  [1, 78, 110],
#  [0, 150, 39],
#  [0, 70, 119],
#  [0, 58, 131],
#  [0, 110, 79],
#  [0, 79, 110],
#  [0, 124, 65],
#  [0, 68, 121],
#  [0, 86, 103],
#  [0, 110, 79],
#  [0, 88, 101],
#  [0, 152, 37],
#  [0, 78, 111],
#  [0, 48, 141],
#  [0, 121, 68],
#  [0, 91, 98],
#  [0, 140, 49],
#  [0, 122, 67],
#  [0, 107, 82],
#  [0, 104, 85],
#  [0, 125, 64],
#  [0, 102, 87],
#  [0, 71, 118],
#  [0, 64, 125],
#  [0, 99, 90],
#  [0, 101, 88],
#  [0, 61, 128],
#  [0, 112, 77],
#  [0, 131, 58],
#  [0, 110, 79],
#  [1, 121, 67],
#  [0, 66, 123],
#  [0, 118, 71],
#  [0, 110, 79]]
