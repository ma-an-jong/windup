# %%
import os
import torch
from torch import nn
import pandas as pd
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader,WeightedRandomSampler
from torch.optim import AdamW,Adam
import torch.nn.functional as F
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_path = '/home/se/paper/legacy/data'

# %%
def get_win(team,date):
    team_win = match.loc[(match['date'] < date) & (match['home'] == team)]
    try:
        return (team_win['home_result'].value_counts()['승']) / len(team_win)
    except:
        return 0

# %%
def get_against_win(home,away,date):
    home_away = match.loc[(match['date'] < date) & (match['home'] == home) & (match['away'] == away)]
    try:
        return (home_away['home_result'].value_counts()['승'])/len(home_away)
    except:
        return 0

# %%
from sklearn.preprocessing import LabelEncoder
class StatDataset(Dataset):
    def __init__(self, match,stat,le):
        
        tmp = []
        label = []
        
        for home_pitcher,home_team,away_pitcher,away_team,home_result,date in list(zip(match['home_pitcher'].values,match['home'].values,match['away_pitcher'],match['away'],match['home_result'],match['date'])):
            home_player_stat = stat.loc[(stat['name'] == home_pitcher) & (stat['team'] == home_team)]
            away_player_stat = stat.loc[(stat['name'] == away_pitcher) & (stat['team'] == away_team)]
            
            home_win = get_win(home_team,date)
            away_win = get_win(away_team,date)
            
            home_away_against = get_against_win(home_team,away_team,date)

            if (len(home_player_stat) != 0) and (len(away_player_stat) != 0):
                vector = home_player_stat.values.tolist()[0][2:] + away_player_stat.values.tolist()[0][2:]
                vector.append(home_win)
                vector.append(away_win)
                vector.append(home_away_against)
                
                tmp.append(vector)
                label.append(home_result)
        
        transform = le.transform(label)
        self.label = torch.tensor(list(transform),dtype=torch.long)
        self.stat = torch.tensor(tmp,dtype=torch.float32)
            
    def __len__(self):
        return len(self.stat)

    def __getitem__(self, index):
        return {
                "stat": self.stat[index],
                "label": self.label[index]
                }
        
    def get_num_batches(self, batch_size):
        return len(self) // batch_size

# %%
class legacyClassifier(nn.Module):
    def __init__(self, dropout=0.5):
        super(legacyClassifier, self).__init__()
        self.linear1 = nn.Linear(39, 1024)
        self.dropout2 = nn.Dropout(dropout)
        self.linear2 = nn.Linear(1024,3)
        
    def forward(self, input_id):
        linear_output = self.linear1(input_id)
        dropout_output1 = self.dropout2(linear_output)
        linear_output1 = self.linear2(dropout_output1)
        return linear_output1

# %%
stat = pd.read_csv(os.path.join(data_path,'average.csv'))
match = pd.read_csv(os.path.join(data_path,'match_day.csv'))
le = LabelEncoder()
_=le.fit(['승','패','무승부'])

# %%
train_match,valid_match = train_test_split(match,shuffle=True,random_state=56)

# %%
train_dataset = StatDataset(train_match,stat,le)
valid_dataset = StatDataset(valid_match,stat,le)
print(len(train_dataset),len(valid_dataset))
# Out:
# 576 189

# %%
batch_size = 16
epochs = 100
device='cuda'

# %%
le.classes_
# Out:
# array(['무승부', '승', '패'], dtype='<U3')

# %%
train_class = pd.DataFrame(train_dataset.label)
train_class_counts = [len(train_class.loc[train_class[0] == 0]) , len(train_class.loc[train_class[0] == 1])  , len(train_class.loc[train_class[0] == 2])]
train_num_samples = sum(train_class_counts)
train_labels = list(train_class.values.reshape(-1))

train_class_weights = [train_num_samples / train_class_counts[i] for i in range(len(train_class_counts))] 

# 해당 데이터의 label에 해당되는 가중치
train_weights = [train_class_weights[train_labels[i]] for i in range(int(train_num_samples))] #해당 레이블마다의 가중치 비율
train_sampler = WeightedRandomSampler(torch.DoubleTensor(train_weights), int(train_num_samples))

# %%
valid_class = pd.DataFrame(valid_dataset.label)
valid_class_counts = [len(valid_class.loc[train_class[0] == 0]) , len(valid_class.loc[train_class[0] == 1])  , len(valid_class.loc[train_class[0] == 2])]
valid_num_samples = sum(valid_class_counts)
valid_labels = list(valid_class.values.reshape(-1))

valid_class_weights = [valid_num_samples / valid_class_counts[i] for i in range(len(valid_class_counts))] 

# 해당 데이터의 label에 해당되는 가중치
valid_weights = [valid_class_weights[valid_labels[i]] for i in range(int(valid_num_samples))] #해당 레이블마다의 가중치 비율
valid_sampler = WeightedRandomSampler(torch.DoubleTensor(valid_weights), int(valid_num_samples))

# %%
train_class_weights
# Out:
# [72.0, 1.8640776699029127, 2.223938223938224]

# %%
valid_class_weights
# Out:
# [94.5, 1.7830188679245282, 2.3333333333333335]

# %%
classifier = legacyClassifier()
classifier.cuda()
optimizer = torch.optim.AdamW(classifier.parameters(), lr=1e-3)

# %%
criterion = nn.CrossEntropyLoss()
_=criterion.cuda()

# %%
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False,sampler = train_sampler)
val_dataloader = DataLoader(valid_dataset, batch_size=batch_size,shuffle=False,sampler = valid_sampler)

# %%
train_loss = []
train_acc = []

valid_loss = []
valid_acc = []

# %%
classifier
# Out:
# legacyClassifier(
#   (linear1): Linear(in_features=39, out_features=1024, bias=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (linear2): Linear(in_features=1024, out_features=3, bias=True)
# )

# %%
classifier.zero_grad()
for epoch in tqdm(range(epochs),total=epochs):

    total_acc_train = 0
    total_loss_train = 0
    classifier.train()
    for i,batch in enumerate(train_dataloader):

        train_label = batch['label'].to(device)
        train_stat = batch['stat'].to(device)
        
        output = classifier(train_stat)
        output = output.squeeze(1)
        batch_loss = criterion(output.float(), train_label)
        
        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()
        
        total_loss_train += batch_loss.item()
        
        correct_prediction = torch.argmax(F.softmax(output, dim=1), 1) == train_label

        acc = correct_prediction.float().mean()
#         acc = (output.round() == train_label).sum().item()
        total_acc_train += acc.item()
        
    train_loss.append(total_loss_train/len(train_dataloader))
    train_acc.append(total_acc_train/len(train_dataloader))
            
    total_acc_val = 0
    total_loss_val = 0
    
    with  torch.no_grad():
        classifier.eval()
        for i,batch in enumerate(val_dataloader):
            
            val_label = batch['label'].to(device)
            val_stat = batch['stat'].to(device)

            output = classifier(val_stat)
            output = output.squeeze(1)
            batch_loss = criterion(output.float(), val_label)
            
            total_loss_val += batch_loss.item()
            correct_prediction = torch.argmax(F.softmax(output, dim=1), 1) == val_label
            acc = correct_prediction.float().mean()
#             acc = (output.round() == val_label).sum().item()
            
            total_acc_val += acc.item()

        valid_loss.append(total_loss_val/ len(val_dataloader))
        valid_acc.append(total_acc_val/ len(val_dataloader))
#         torch.save(classifier.state_dict(), './model{}.pt'.format(epoch))
 
        print(
                f'Epochs: {epoch + 1} | Train Loss: {total_loss_train / len(train_dataloader): .3f} \
                | Train Accuracy: {total_acc_train / len(train_dataloader): .3f} \
                | Val Loss: {total_loss_val / len(val_dataloader): .3f} \
                | Val Accuracy: {total_acc_val / len(val_dataloader): .3f}')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#
# Epochs: 54 | Train Loss:  0.799                 | Train Accuracy:  0.632                 | Val Loss:  0.849                 | Val Accuracy:  0.494
# Epochs: 55 | Train Loss:  0.795                 | Train Accuracy:  0.632                 | Val Loss:  0.968                 | Val Accuracy:  0.482
# Epochs: 56 | Train Loss:  0.780                 | Train Accuracy:  0.611                 | Val Loss:  0.938                 | Val Accuracy:  0.474
# Epochs: 57 | Train Loss:  0.876                 | Train Accuracy:  0.587                 | Val Loss:  0.874                 | Val Accuracy:  0.516
# Epochs: 58 | Train Loss:  0.824                 | Train Accuracy:  0.620                 | Val Loss:  1.101                 | Val Accuracy:  0.399
# Epochs: 59 | Train Loss:  0.837                 | Train Accuracy:  0.566                 | Val Loss:  1.032                 | Val Accuracy:  0.470
# Epochs: 60 | Train Loss:  0.830                 | Train Accuracy:  0.623                 | Val Loss:  0.955                 | Val Accuracy:  0.464
# Epochs: 61 | Train Loss:  0.720                 | Train Accuracy:  0.661                 | Val Loss:  0.942                 | Val Accuracy:  0.447
# Epochs: 62 | Train Loss:  0.742                 | Train Accuracy:  0.653                 | Val Loss:  1.209                 | Val Accuracy:  0.438
# Epochs: 63 | Train Loss:  0.785                 | Train Accuracy:  0.620                 | Val Loss:  0.953                 | Val Accuracy:  0.467
# Epochs: 64 | Train Loss:  0.765                 | Train Accuracy:  0.658                 | Val Loss:  0.954                 | Val Accuracy:  0.447
# Epochs: 65 | Train Loss:  0.735                 | Train Accuracy:  0.630                 | Val Loss:  0.886                 | Val Accuracy:  0.429
# Epochs: 66 | Train Loss:  0.826                 | Train Accuracy:  0.628                 | Val Loss:  0.883                 | Val Accuracy:  0.478
# Epochs: 67 | Train Loss:  0.730                 | Train Accuracy:  0.641                 | Val Loss:  1.100                 | Val Accuracy:  0.393
# Epochs: 68 | Train Loss:  0.780                 | Train Accuracy:  0.613                 | Val Loss:  0.880                 | Val Accuracy:  0.490
# Epochs: 69 | Train Loss:  0.746                 | Train Accuracy:  0.628                 | Val Loss:  0.882                 | Val Accuracy:  0.495
# Epochs: 70 | Train Loss:  0.750                 | Train Accuracy:  0.606                 | Val Loss:  0.848                 | Val Accuracy:  0.504
# Epochs: 71 | Train Loss:  0.842                 | Train Accuracy:  0.609                 | Val Loss:  1.000                 | Val Accuracy:  0.472
# Epochs: 72 | Train Loss:  0.749                 | Train Accuracy:  0.634                 | Val Loss:  0.880                 | Val Accuracy:  0.425
# Epochs: 73 | Train Loss:  0.846                 | Train Accuracy:  0.576                 | Val Loss:  1.077                 | Val Accuracy:  0.438
# Epochs: 74 | Train Loss:  0.752                 | Train Accuracy:  0.658                 | Val Loss:  0.901                 | Val Accuracy:  0.515
# Epochs: 75 | Train Loss:  0.863                 | Train Accuracy:  0.602                 | Val Loss:  1.013                 | Val Accuracy:  0.484
# Epochs: 76 | Train Loss:  0.825                 | Train Accuracy:  0.639                 | Val Loss:  1.140                 | Val Accuracy:  0.466
# Epochs: 77 | Train Loss:  0.790                 | Train Accuracy:  0.649                 | Val Loss:  0.918                 | Val Accuracy:  0.470
# Epochs: 78 | Train Loss:  0.740                 | Train Accuracy:  0.644                 | Val Loss:  1.051                 | Val Accuracy:  0.531
# Epochs: 79 | Train Loss:  0.766                 | Train Accuracy:  0.653                 | Val Loss:  0.906                 | Val Accuracy:  0.505
# Epochs: 80 | Train Loss:  0.759                 | Train Accuracy:  0.634                 | Val Loss:  1.069                 | Val Accuracy:  0.469
# Epochs: 81 | Train Loss:  0.755                 | Train Accuracy:  0.594                 | Val Loss:  0.931                 | Val Accuracy:  0.562
# Epochs: 82 | Train Loss:  0.772                 | Train Accuracy:  0.639                 | Val Loss:  1.148                 | Val Accuracy:  0.394
# Epochs: 83 | Train Loss:  0.724                 | Train Accuracy:  0.639                 | Val Loss:  0.842                 | Val Accuracy:  0.528
# Epochs: 84 | Train Loss:  0.746                 | Train Accuracy:  0.644                 | Val Loss:  0.944                 | Val Accuracy:  0.508
# Epochs: 85 | Train Loss:  0.776                 | Train Accuracy:  0.627                 | Val Loss:  0.866                 | Val Accuracy:  0.454
# Epochs: 86 | Train Loss:  0.664                 | Train Accuracy:  0.655                 | Val Loss:  1.027                 | Val Accuracy:  0.467
# Epochs: 87 | Train Loss:  0.767                 | Train Accuracy:  0.651                 | Val Loss:  1.170                 | Val Accuracy:  0.429
# Epochs: 88 | Train Loss:  0.733                 | Train Accuracy:  0.623                 | Val Loss:  0.826                 | Val Accuracy:  0.471
# Epochs: 89 | Train Loss:  0.718                 | Train Accuracy:  0.644                 | Val Loss:  0.918                 | Val Accuracy:  0.434
# Epochs: 90 | Train Loss:  0.712                 | Train Accuracy:  0.677                 | Val Loss:  0.861                 | Val Accuracy:  0.497
# Epochs: 91 | Train Loss:  0.683                 | Train Accuracy:  0.658                 | Val Loss:  0.883                 | Val Accuracy:  0.478
# Epochs: 92 | Train Loss:  0.703                 | Train Accuracy:  0.658                 | Val Loss:  0.865                 | Val Accuracy:  0.525
# Epochs: 93 | Train Loss:  0.777                 | Train Accuracy:  0.651                 | Val Loss:  0.957                 | Val Accuracy:  0.464
# Epochs: 94 | Train Loss:  0.727                 | Train Accuracy:  0.641                 | Val Loss:  1.055                 | Val Accuracy:  0.442
# Epochs: 95 | Train Loss:  0.760                 | Train Accuracy:  0.653                 | Val Loss:  0.864                 | Val Accuracy:  0.475
# Epochs: 96 | Train Loss:  0.787                 | Train Accuracy:  0.606                 | Val Loss:  0.925                 | Val Accuracy:  0.445
# Epochs: 97 | Train Loss:  0.759                 | Train Accuracy:  0.642                 | Val Loss:  1.054                 | Val Accuracy:  0.355
# Epochs: 98 | Train Loss:  0.776                 | Train Accuracy:  0.616                 | Val Loss:  0.865                 | Val Accuracy:  0.460
# Epochs: 99 | Train Loss:  0.732                 | Train Accuracy:  0.635                 | Val Loss:  0.916                 | Val Accuracy:  0.532
# Epochs: 100 | Train Loss:  0.739                 | Train Accuracy:  0.658                 | Val Loss:  0.936                 | Val Accuracy:  0.489

# %%
plt.plot(valid_loss,color='red',label = 'valid')
plt.plot(train_loss,color='blue',label = 'train')
plt.show()

# %%
plt.plot(valid_acc,color='red',label = 'valid')
plt.plot(train_acc,color='blue',label = 'train')
plt.show()

# %%
col = list(stat.columns[2:]) + list(stat.columns[2:]) + ['home_win','away_win','home_away_against']
corr = pd.DataFrame(train_dataset.stat.numpy(),columns=col)
df_corr = corr.corr(method='pearson',min_periods=1)

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df_corr, annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')
plt.yticks(rotation=0)
plt.savefig('heatmap.png',dpi = 100)
plt.show()
