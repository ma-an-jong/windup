# %%
import pandas as pd
import os

# %%
dir_path = '/home/se/paper/legacy/data'

# %%
match = pd.read_csv(os.path.join(dir_path,'match_day.csv'))

# %%
match['date'].unique()
# Out:
# array([20200505, 20200506, 20200507, 20200508, 20200509, 20200510,
#        20200512, 20200513, 20200514, 20200515, 20200516, 20200517,
#        20200519, 20200520, 20200521, 20200522, 20200523, 20200524,
#        20200526, 20200527, 20200528, 20200529, 20200530, 20200531,
#        20200602, 20200603, 20200604, 20200605, 20200606, 20200607,
#        20200609, 20200610, 20200611, 20200612, 20200613, 20200614,
#        20200616, 20200617, 20200618, 20200619, 20200620, 20200621,
#        20200623, 20200624, 20200625, 20200626, 20200627, 20200628,
#        20200630, 20200701, 20200702, 20200703, 20200704, 20200705,
#        20200707, 20200708, 20200709, 20200710, 20200711, 20200713,
#        20200714, 20200715, 20200716, 20200717, 20200718, 20200719,
#        20200721, 20200722, 20200724, 20200725, 20200726, 20200727,
#        20200728, 20200729, 20200730, 20200731, 20200801, 20200802,
#        20200804, 20200805, 20200806, 20200807, 20200808, 20200809,
# ...

# %%
pitcher_stat = pd.read_csv(os.path.join(dir_path,'pitcher_stat.csv'))

# %%
pitcher_stat
# Out:
#        name team oppositeTeam  w  l  save  hld  blown  game  gs  ...      k  \
# 0       박세웅   롯데           두산  2  0     0    0      0     4   4  ...   4.85
# 1       이인복   롯데           두산  0  0     0    0      0     3   1  ...  12.79
# 2       김원중   롯데           두산  1  0     3    0      1     5   0  ...   8.44
# 3       프랑코   롯데           두산  2  0     0    0      0     4   3  ...   8.10
# 4     스트레일리   롯데           두산  1  2     0    0      0     4   4  ...   7.52
# ...     ...  ...          ... .. ..   ...  ...    ...   ...  ..  ...    ...
# 2035     양현   키움          SSG  0  1     0    0      0     6   0  ...   5.79
# 2036    문성현   키움          SSG  0  0     0    0      0     1   0  ...    0.0
# 2037    김정인   키움          SSG  0  0     0    0      0     2   2  ...    9.0
# 2038    이승호   키움          SSG  0  1     0    0      0     5   0  ...   4.15
# 2039    김태훈   키움          SSG  0  0     1    1      2     9   0  ...    4.0
#
# ...

# %%
average = pd.read_csv(os.path.join(dir_path,'average.csv'))

# %%
average
# Out:
#       name team         w         l      save  hld     blown      game  \
# 0      박세웅   롯데  0.125000  0.000000  0.000000  0.0  0.000000  0.500000
# 1      이인복   롯데  0.125000  0.000000  0.000000  0.0  0.000000  0.250000
# 2      김원중   롯데  0.111111  0.222222  0.444444  0.0  0.111111  0.888889
# 3      프랑코   롯데  0.000000  0.111111  0.000000  0.0  0.000000  0.444444
# 4    스트레일리   롯데  0.111111  0.111111  0.000000  0.0  0.000000  0.444444
# ..     ...  ...       ...       ...       ...  ...       ...       ...
# 303    브리검   키움  0.400000  0.000000  0.000000  0.0  0.000000  0.400000
# 304    스미스   키움  0.500000  0.000000  0.000000  0.0  0.000000  0.500000
# 305    박관진   키움  0.000000  0.000000  0.000000  0.0  0.000000  0.500000
# 306    문성현   키움  0.000000  0.000000  0.000000  0.0  0.000000  0.250000
# 307    조영건   키움  0.000000  0.000000  0.000000  0.0  0.000000  1.000000
#
#            gs        ip          k         bb        hr     babip         lob  \
# ...

# %%
article = pd.read_csv(os.path.join(dir_path,'article.csv'))

# %%
article
# Out:
#        team      date      time  \
# 0        키움  20160101  오전 09:16
# 1        키움  20160101  오전 05:51
# 2        키움  20160103  오후 03:09
# 3        키움  20160103  오후 12:26
# 4        키움  20160103  오전 06:04
# ...     ...       ...       ...
# 134246   롯데  20210711  오전 07:10
# 134247   롯데  20210711  오전 07:00
# 134248   롯데  20210712  오전 10:35
# 134249   롯데  20210712  오전 08:08
# 134250   롯데  20210712  오전 07:23
#
#                                                     image  \
# 0       https://imgnews.pstatic.net/image/421/2016/01/...
# 1       https://imgnews.pstatic.net/image/109/2016/01/...
# 2       https://imgnews.pstatic.net/image/396/2016/01/...
# 3       https://imgnews.pstatic.net/image/477/2016/01/...
# 4       https://imgnews.pstatic.net/image/109/2016/01/...
# ...                                                   ...
# 134246  https://imgnews.pstatic.net/image/311/2021/07/...
# 134247  https://imgnews.pstatic.net/image/117/2021/07/...
# ...

# %%
kobert_dataset = pd.read_csv('/home/se/paper/classifier/refined_dataset.csv')

# %%
kobert_dataset
# Out:
#                                                  context  label
# 0      KBO리그는 비약적인 발전을 했지만  코로나 19  사태와 각종 사고로 인해 인기는...      1
# 1       디펜딩 챔피언  KT 위즈의 에이스 윌리엄 쿠에바스가 여전한 위용을 과시했다 쿠에...      1
# 2      2일 경기도 수원케이티위즈파크에서 열린 2022 KBO리그 프로야구 개막전 삼성 라...      1
# 3      2일 오후 경기 수원 장안구 KT위즈파크에서 열린  2022 신한은행 SOL KBO...      1
# 4       삼성과 타이 브레이크에서 이겼던 영향이 어느 정도 있다고 생각한다  kt 에이스 ...      1
# ...                                                  ...    ...
# 23188   한화 이글스의 새 외국인 투수 예프리 라미레즈가 두 번째 등판에서는  외인다운  ...      1
# 23189  5월 15일 대전 롯데 자이언츠전 5회말  한화 이글스 2루수 정은원은 박세웅을 상...      1
# 23190  지난 21일 LG 상대로 KBO리그 데뷔전에서 한화 선발투수 라미레즈가 교체돼 더그...      1
# 23191  2021년 9월 13일 서울 블루스퀘어에서 열린 2022 신인 드래프트  제공   ...      1
# 23192  최하위로 처진 한화가 2군에서 희망을 찾을 수 있을까  일단 기대할 만한 선수들이 ...      1
#
# [23193 rows x 2 columns]
